# %% [markdown]
# <a href="https://colab.research.google.com/github/rabebsdiri45/tts-spongebob-voice-clone/blob/main/wavs_preproccessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This code prepares the Spongebob dataset for use in training a TTS model. The dataset consists of WAV files containing Spongebob's voice,
#  which were collected for this project. The code performs tasks such as file formatting, preprocessing, and data cleaning to ensure that
#   the dataset is properly formatted and ready for use in training the TTS model.

# %% [markdown]
# **Install Coqui TTS**

# %%
# !sudo apt-get install espeak-ng
# !git clone https://github.com/coqui-ai/TTS
# !pip install TTS

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
#checking the sample rate of wav files
import os
import librosa

# Set the path to your folder containing the WAV files
folder_path = '/content/drive/MyDrive/VoiceCloning/datasets/wavs'

# Loop over all files in the folder with .wav extension
for file_name in os.listdir(folder_path):
    if file_name.endswith('.wav'):
        file_path = os.path.join(folder_path, file_name)
        audio, sr = librosa.load(file_path, sr=None)
        print(f'File name: {file_name}, Sample rate: {sr}')

# %% [markdown]
# the sample rate=32000

# %%
import os
ds_name = "vits-vctk-narrator-22k-ds" #@param {type:"string"}
output_directory = "traineroutput" #@param {type:"string"}
upload_dir = "wavs" #@param {type:"string"}
#MODEL_FILE = "/root/.local/share/tts/tts_models--en--ljspeech--vits/model_file.pth" #@param {type:"string"}
MODEL_FILE = "/root/.local/share/tts/tts_models--en--vctk--vits/model_file.pth" #@param {type:"string"}
upload_dir = "/content/drive/MyDrive/" + upload_dir
RUN_NAME = "VITS-en" #@param {type:"string"}


OUT_PATH = "/content/drive/MyDrive/"+ds_name+"/traineroutput/"
# !mkdir $upload_dir
# !mkdir /content/drive/MyDrive/$ds_name

# %%
#@title
# %cd $upload_dir
# !ls -al

# %% [markdown]
# **SNR :SIGNAL-TO-NOISE RATIO**

# %% [markdown]
# Signal-to-noise ratio (SNR) is a measure of the strength of a signal relative to the background noise present in a system. It is typically expressed as a ratio of the power of the signal to the power of the noise, and is often measured in decibels (dB).
#
# A higher SNR indicates that the signal is stronger relative to the noise, which can lead to improved signal quality and more accurate measurements or analysis.

# %%
import os
import glob
import subprocess
import IPython
import soundfile as sf
import numpy as np
from tqdm import tqdm
from multiprocessing import Pool
from matplotlib import pylab as plt
# %matplotlib inline

# %%
# !curl http://www.cs.cmu.edu/~robust/archive/algorithms/WADA_SNR_IS_2008/WadaSNR.tar.gz --output /content/drive/MyDrive/VoiceCloning/WadaSNR/WadaSNR.tar.gz
# %cd /content/drive/MyDrive/VoiceCloning/TTS/WadaSNR
# !tar -xvf /content/drive/MyDrive/VoiceCloning/WadaSNR/WadaSNR.tar.gz -C /content/drive/MyDrive/VoiceCloning/WadaSNR
# %cd ..

# %%
# Set the meta parameters
DATA_PATH = "/content/drive/MyDrive/VoiceCloning/[dataset]" 
NUM_PROC = 1
CURRENT_PATH = '/content/drive/MyDrive/VoiceCloning'

# %% [markdown]
# Set Up SNR Evaulation

# %%
def compute_file_snr(file_path):
    """ Convert given file to required format with FFMPEG and process with WADA."""
    _, sr = sf.read(file_path)
    new_file = file_path.replace(".wav", "_tmp.wav")
    if sr != 16000:
        command = f'ffmpeg -i "{file_path}" -ac 1 -acodec pcm_s16le -y -ar 16000 "{new_file}"'
    else:
        command = f'cp "{file_path}" "{new_file}"'
    os.system(command)
    command = [f'"{CURRENT_PATH}/WadaSNR/Exe/WADASNR"', f'-i "{new_file}"', f'-t "{CURRENT_PATH}/WadaSNR/Exe/Alpha0.400000.txt"', '-ifmt mswav']
    output = subprocess.check_output(" ".join(command), shell=True)
    try:
        output = float(output.split()[-3].decode("utf-8"))
    except:
        raise RuntimeError(" ".join(command))
    os.system(f'rm "{new_file}"')
    return output, file_path

# %% [markdown]
# Confirm the amount of wav files the dataset has

# %%
import glob
wav_files = glob.glob(f"{DATA_PATH}/**/*.wav", recursive=True)
print(f" > Number of wav files {len(wav_files)}")

# %% [markdown]
# Processes Dataset for SNR

# %%
if NUM_PROC == 1:
    file_snrs = [None] * len(wav_files) 
    for idx, wav_file in tqdm(enumerate(wav_files)):
        tup = compute_file_snr(wav_file)
        file_snrs[idx] = tup
else:
    with Pool(NUM_PROC) as pool:
        file_snrs = list(tqdm(pool.imap(compute_file_snr, wav_files), total=len(wav_files)))

# %% [markdown]
# Calculates Average SNR (Higher the better, max 100)

# %%
snrs = [tup[0] for tup in file_snrs]

error_idxs = np.where(np.isnan(snrs) == True)[0]
error_files = [wav_files[idx] for idx in error_idxs]

file_snrs = [i for j, i in enumerate(file_snrs) if j not in error_idxs]
file_names = [tup[1] for tup in file_snrs]
snrs = [tup[0] for tup in file_snrs]
file_idxs = np.argsort(snrs)


print(f" > Average SNR of the dataset:{np.mean(snrs)}")

# %%
def output_snr_with_audio(idx):
    file_idx = file_idxs[idx]
    file_name = file_names[file_idx]
    wav, sr = sf.read(file_name)
    # multi channel to single channel
    if len(wav.shape) == 2:
        wav = wav[:, 0]
    print(f" > {file_name} - snr:{snrs[file_idx]}")
    IPython.display.display(IPython.display.Audio(wav, rate=sr))

# %% [markdown]
# Calculate Worst & Best Performing Audio Files

# %%
# find worse SNR files
N = 10  # number of files to fetch
for i in range(N):
    output_snr_with_audio(i)

# %%
# find best recordings
N = 10  # number of files to fetch
for i in range(N):
    output_snr_with_audio(-i-1)

# %% [markdown]
# **Demucs on Uploaded Samples**

# %% [markdown]
# Samples will be moved to subdirectory named backup
#
# Vocals.wav will be renamed to [samplefile].wav, resampled to 22khz mono, and moved back to the sample working directory.
#
# Final output is mono 22khz wav.

# %%
# !pip install demucs

# %%
S_D_WORKDIR = "/content/drive/MyDrive/wavs/" 
S_D_EXT = "wav"

# %%
S_D_SCRIPT="""
#!/bin/bash
EXT='"""+S_D_EXT+"""'
WORK_DIR='"""+S_D_WORKDIR+"""'
rename 's/\.([^.]+)$/.\L$1/' "$WORK_DIR"/*
cd "$WORK_DIR"
mkdir backup
mv *.$EXT backup
demucs --two-stems=vocals -n htdemucs_ft backup/*.$EXT
cd separated/htdemucs_ft
for dir in */; do
	echo "$dir"
	cd "$dir"
	dir="${dir%/}"
	ffmpeg -i vocals.wav -ar 22050 -ac 1 "$dir".wav
	mv "$dir".wav $WORK_DIR
	cd ..
done
cd "$WORK_DIR"
rm -rf separated
"""
with open('/content/drive/MyDrive/script-demucs-samples.sh', 'w') as file:
  file.write(S_D_SCRIPT)

# %%
# !sh /content/drive/MyDrive/script-demucs-samples.sh

# %% [markdown]
# **NORMALIZE-AUDIO**

# %% [markdown]
# normalize files to -27dbFS.

# %%
# !apt-get install normalize-audio

# %%
N_EXT = "wav" 
N_WORKDIR = "/content/drive/MyDrive/wavs"

# %%
#@title
N_SCRIPT="""
#!/bin/bash
EXT='"""+N_EXT+"""'
WORK_DIR='"""+N_WORKDIR+"""'
rename 's/\.([^.]+)$/.\L$1/' "$WORK_DIR"/*
cd "$WORK_DIR"
normalize-audio -a -27dBFS *.$EXT
"""
with open('/content/drive/MyDrive/script-normalize.sh', 'w') as file:
  file.write(N_SCRIPT)

# %%
# !sh /content/drive/MyDrive/script-normalize.sh

# %%
# !pip install librosa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: librosa in /usr/local/lib/python3.9/dist-packages (0.10.0.post2)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from librosa) (1.10.1)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.9/dist-packages (from librosa) (0.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.9/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.9/dist-packages (from librosa) (0.3.4)
# Requirement already satisfied: pooch<1.7,>=1.0 in /usr/local/lib/python3.9/dist-packages (from librosa) (1.6.0)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/lib/python3.9/dist-packages (from librosa) (1.22.4)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.9/dist-packages (from librosa) (0.56.4)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.9/dist-packages (from librosa) (0.12.1)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.9/dist-packages (from librosa) (1.0.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.9/dist-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.9/dist-packages (from librosa) (1.1.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.9/dist-packages (from librosa) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.9/dist-packages (from librosa) (4.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.51.0->librosa) (67.6.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.51.0->librosa) (0.39.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from pooch<1.7,>=1.0->librosa) (2.27.1)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from pooch<1.7,>=1.0->librosa) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from pooch<1.7,>=1.0->librosa) (23.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.20.0->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.9/dist-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2022.12.7)

# %%
import numpy as np
import librosa
import os

# Path to the folder containing the audio files
folder_path = "/content/drive/MyDrive/wavs/backup"

for file_name in os.listdir(folder_path):
    if file_name.endswith('.wav'):
        # Load audio file
        file_path = os.path.join(folder_path, file_name)
        audio, sr = librosa.load(file_path, sr=16000)

        # Compute the root mean square (RMS) energy of the audio
        rms = librosa.feature.rms(y=audio)[0]

        # Compute the median value of the RMS energy
        median_rms = np.median(rms)

        # Print the median RMS energy
        print(f"File: {file_name} - Median RMS energy: {median_rms}")
        if median_rms < 0.01:
            print(f"The audio file {filename} contains white silence.")
        # else:
        #     print(f"The audio file {filename} does not contain white silence.")
# Out:
# File: LJ001-0090.wav - Median RMS energy: 0.08819131553173065
# File: LJ002-0145.wav - Median RMS energy: 0.0844791978597641
# File: LJ002-0107.wav - Median RMS energy: 0.11311400681734085
# File: LJ001-0076.wav - Median RMS energy: 0.08749743551015854
# File: LJ002-0204.wav - Median RMS energy: 0.08874053508043289
# File: LJ003-0040.wav - Median RMS energy: 0.08424635231494904
# File: LJ001-0006.wav - Median RMS energy: 0.10674095898866653
# File: LJ002-0186.wav - Median RMS energy: 0.07650020718574524
# File: LJ001-0151.wav - Median RMS energy: 0.08721309900283813
# File: LJ002-0025.wav - Median RMS energy: 0.10257001966238022
# File: LJ002-0036.wav - Median RMS energy: 0.0812864601612091
# File: LJ003-0278.wav - Median RMS energy: 0.09330209344625473
# File: LJ001-0101.wav - Median RMS energy: 0.101053886115551
# File: LJ001-0178.wav - Median RMS energy: 0.10626619309186935
# File: LJ003-0123.wav - Median RMS energy: 0.07805871963500977
# File: LJ003-0174.wav - Median RMS energy: 0.08261675387620926
# File: LJ003-0204.wav - Median RMS energy: 0.08457222580909729
# File: LJ002-0284.wav - Median RMS energy: 0.09979915618896484
# File: LJ002-0303.wav - Median RMS energy: 0.07590200006961823
# File: LJ002-0332.wav - Median RMS energy: 0.10723461955785751
# File: LJ003-0296.wav - Median RMS energy: 0.1052800640463829
# File: LJ002-0118.wav - Median RMS energy: 0.08807697892189026
# File: LJ003-0266.wav - Median RMS energy: 0.1166028156876564
# File: LJ002-0180.wav - Median RMS energy: 0.08101341873407364
# File: LJ002-0096.wav - Median RMS energy: 0.08990272879600525
# File: LJ001-0163.wav - Median RMS energy: 0.0789337158203125
# File: LJ003-0173.wav - Median RMS energy: 0.08128818869590759
# File: LJ002-0027.wav - Median RMS energy: 0.10900412499904633
# File: LJ001-0130.wav - Median RMS energy: 0.10521876811981201
# File: LJ003-0024.wav - Median RMS energy: 0.110079824924469
# File: LJ002-0239.wav - Median RMS energy: 0.10551244020462036
# File: LJ003-0300.wav - Median RMS energy: 0.09412983804941177
# File: LJ002-0006.wav - Median RMS energy: 0.09004159271717072
# File: LJ002-0287.wav - Median RMS energy: 0.09515763819217682
# File: LJ002-0286.wav - Median RMS energy: 0.1136622354388237
# File: LJ003-0282.wav - Median RMS energy: 0.11038493365049362
# File: LJ002-0152.wav - Median RMS energy: 0.10440950840711594
# File: LJ003-0156.wav - Median RMS energy: 0.09717331826686859
# File: LJ001-0167.wav - Median RMS energy: 0.07926850020885468
# File: LJ002-0005.wav - Median RMS energy: 0.12331138551235199
# File: LJ002-0222.wav - Median RMS energy: 0.11728110909461975
# File: LJ003-0145.wav - Median RMS energy: 0.1038750559091568
# File: LJ001-0086.wav - Median RMS energy: 0.08797562122344971
# File: LJ003-0009.wav - Median RMS energy: 0.11130913347005844
# File: LJ003-0069.wav - Median RMS energy: 0.09752026945352554
# File: LJ002-0218.wav - Median RMS energy: 0.09262966364622116
# File: LJ002-0215.wav - Median RMS energy: 0.06976701319217682
# File: LJ003-0117.wav - Median RMS energy: 0.08193040639162064
# File: LJ003-0006.wav - Median RMS energy: 0.0952112153172493
# File: LJ002-0002.wav - Median RMS energy: 0.0944410040974617
# File: LJ003-0007.wav - Median RMS energy: 0.08533865213394165
# File: LJ004-0025.wav - Median RMS energy: 0.07801517844200134
# File: LJ002-0080.wav - Median RMS energy: 0.07998231798410416
# File: LJ002-0031.wav - Median RMS energy: 0.07098592072725296
# File: LJ001-0184.wav - Median RMS energy: 0.10627840459346771
# File: LJ003-0182.wav - Median RMS energy: 0.09947822988033295
# File: LJ003-0101.wav - Median RMS energy: 0.07980615645647049
# File: LJ003-0238.wav - Median RMS energy: 0.08426152914762497
# File: LJ001-0186.wav - Median RMS energy: 0.1101406067609787
# File: LJ002-0064.wav - Median RMS energy: 0.0881873294711113
# File: LJ003-0027.wav - Median RMS energy: 0.10907171666622162
# File: LJ003-0073.wav - Median RMS energy: 0.0723840668797493
# File: LJ001-0182.wav - Median RMS energy: 0.07758523523807526
# File: LJ002-0282.wav - Median RMS energy: 0.08778651058673859
# File: LJ001-0080.wav - Median RMS energy: 0.1172432154417038
# File: LJ002-0250.wav - Median RMS energy: 0.11319412291049957
# File: LJ003-0315.wav - Median RMS energy: 0.09596972167491913
# File: LJ002-0137.wav - Median RMS energy: 0.094827800989151
# File: LJ003-0058.wav - Median RMS energy: 0.09244740009307861
# File: LJ002-0065.wav - Median RMS energy: 0.09155203402042389
# File: LJ002-0103.wav - Median RMS energy: 0.07297128438949585
# File: LJ002-0163.wav - Median RMS energy: 0.10535190999507904
# File: LJ002-0207.wav - Median RMS energy: 0.10753225535154343
# File: LJ001-0104.wav - Median RMS energy: 0.0920485109090805
# File: LJ003-0221.wav - Median RMS energy: 0.09931318461894989
# File: LJ001-0037.wav - Median RMS energy: 0.05921630188822746
# File: LJ003-0022.wav - Median RMS energy: 0.08973144739866257
# File: LJ002-0203.wav - Median RMS energy: 0.09382250905036926
# File: LJ002-0066.wav - Median RMS energy: 0.09285087883472443
# File: LJ002-0314.wav - Median RMS energy: 0.10013654828071594
# File: LJ002-0211.wav - Median RMS energy: 0.0856582298874855
# File: LJ002-0328.wav - Median RMS energy: 0.10361521691083908
# File: LJ003-0090.wav - Median RMS energy: 0.12295681238174438
# File: LJ002-0191.wav - Median RMS energy: 0.08870898187160492
# File: LJ001-0041.wav - Median RMS energy: 0.08190644532442093
# File: LJ003-0285.wav - Median RMS energy: 0.07918193191289902
# File: LJ003-0045.wav - Median RMS energy: 0.1093674898147583
# File: LJ003-0328.wav - Median RMS energy: 0.10583428293466568
# File: LJ003-0137.wav - Median RMS energy: 0.11444900184869766
# File: LJ003-0033.wav - Median RMS energy: 0.09548851102590561
# File: LJ003-0063.wav - Median RMS energy: 0.09183992445468903
# File: LJ002-0146.wav - Median RMS energy: 0.08099623769521713
# File: LJ002-0223.wav - Median RMS energy: 0.10603854805231094
# File: LJ002-0181.wav - Median RMS energy: 0.09789567440748215
# File: LJ002-0147.wav - Median RMS energy: 0.0847429484128952
# File: LJ003-0151.wav - Median RMS energy: 0.09288620948791504
# File: LJ003-0166.wav - Median RMS energy: 0.08687609434127808
# File: LJ002-0150.wav - Median RMS energy: 0.11574456095695496
# File: LJ002-0198.wav - Median RMS energy: 0.10601459443569183
# File: LJ004-0011.wav - Median RMS energy: 0.12868276238441467
# File: LJ001-0161.wav - Median RMS energy: 0.09558869898319244
# File: LJ003-0136.wav - Median RMS energy: 0.09643889963626862
# File: LJ001-0064.wav - Median RMS energy: 0.07989378273487091
# File: LJ003-0088.wav - Median RMS energy: 0.08869887888431549
# File: LJ002-0179.wav - Median RMS energy: 0.08875861018896103
# File: LJ002-0169.wav - Median RMS energy: 0.10905960202217102
# File: LJ004-0009.wav - Median RMS energy: 0.10547753423452377
# File: LJ001-0157.wav - Median RMS energy: 0.092009998857975
# File: LJ001-0144.wav - Median RMS energy: 0.0972602516412735
# File: LJ001-0057.wav - Median RMS energy: 0.10171106457710266
# File: LJ001-0066.wav - Median RMS energy: 0.08348289877176285
# File: LJ001-0062.wav - Median RMS energy: 0.1087942123413086
# File: LJ002-0016.wav - Median RMS energy: 0.09687453508377075
# File: LJ002-0323.wav - Median RMS energy: 0.11217760294675827
# File: LJ003-0252.wav - Median RMS energy: 0.08648349344730377
# File: LJ002-0029.wav - Median RMS energy: 0.08665404468774796
# File: LJ002-0338.wav - Median RMS energy: 0.08681780099868774
# File: LJ002-0259.wav - Median RMS energy: 0.08311766386032104
# File: LJ002-0201.wav - Median RMS energy: 0.10665245354175568
# File: LJ003-0330.wav - Median RMS energy: 0.0966830775141716
# File: LJ003-0059.wav - Median RMS energy: 0.08081776648759842
# File: LJ002-0123.wav - Median RMS energy: 0.07502155005931854
# File: LJ002-0111.wav - Median RMS energy: 0.07980604469776154
# File: LJ003-0168.wav - Median RMS energy: 0.09531383961439133
# File: LJ002-0049.wav - Median RMS energy: 0.07965172827243805
# File: LJ002-0274.wav - Median RMS energy: 0.07468569278717041
# File: LJ001-0036.wav - Median RMS energy: 0.08985399454832077
# File: LJ003-0157.wav - Median RMS energy: 0.09284265339374542
# File: LJ002-0076.wav - Median RMS energy: 0.0963176041841507
# File: LJ004-0015.wav - Median RMS energy: 0.07871930301189423
# File: LJ002-0258.wav - Median RMS energy: 0.09801015257835388
# File: LJ003-0158.wav - Median RMS energy: 0.12100929021835327
# File: LJ001-0071.wav - Median RMS energy: 0.10268354415893555
# File: LJ003-0120.wav - Median RMS energy: 0.06910130381584167
# File: LJ003-0034.wav - Median RMS energy: 0.09601092338562012
# File: LJ002-0319.wav - Median RMS energy: 0.08431964367628098
# File: LJ003-0258.wav - Median RMS energy: 0.09278798848390579
# File: LJ003-0281.wav - Median RMS energy: 0.10054373741149902
# File: LJ002-0243.wav - Median RMS energy: 0.0821724534034729
# File: LJ002-0057.wav - Median RMS energy: 0.0957990512251854
# File: LJ002-0102.wav - Median RMS energy: 0.09636376798152924
# File: LJ002-0074.wav - Median RMS energy: 0.0968555435538292
# File: LJ002-0313.wav - Median RMS energy: 0.08863073587417603
# File: LJ003-0293.wav - Median RMS energy: 0.08490894734859467
# File: LJ002-0325.wav - Median RMS energy: 0.07386215776205063
# File: LJ002-0034.wav - Median RMS energy: 0.07188387215137482
# File: LJ001-0009.wav - Median RMS energy: 0.08942040801048279
# File: LJ002-0045.wav - Median RMS energy: 0.1307457685470581
# File: LJ001-0035.wav - Median RMS energy: 0.08001695573329926
# File: LJ002-0121.wav - Median RMS energy: 0.08131975680589676
# File: LJ004-0022.wav - Median RMS energy: 0.08475039899349213
# File: LJ001-0100.wav - Median RMS energy: 0.08353065699338913
# File: LJ003-0205.wav - Median RMS energy: 0.10837127268314362
# File: LJ002-0161.wav - Median RMS energy: 0.11841687560081482
# File: LJ002-0033.wav - Median RMS energy: 0.09673880785703659
# File: LJ003-0323.wav - Median RMS energy: 0.08775840699672699
# File: LJ003-0202.wav - Median RMS energy: 0.10001729428768158
# File: LJ002-0236.wav - Median RMS energy: 0.13196779787540436
# File: LJ002-0058.wav - Median RMS energy: 0.07506431639194489
# File: LJ003-0087.wav - Median RMS energy: 0.09257911145687103
# File: LJ003-0276.wav - Median RMS energy: 0.10095459967851639
# File: LJ002-0335.wav - Median RMS energy: 0.09642623364925385
# File: LJ001-0084.wav - Median RMS energy: 0.07620738446712494
# File: LJ002-0249.wav - Median RMS energy: 0.09360309690237045
# File: LJ003-0313.wav - Median RMS energy: 0.1094827800989151
# File: LJ002-0251.wav - Median RMS energy: 0.09316227585077286
# File: LJ002-0070.wav - Median RMS energy: 0.10300752520561218
# File: LJ003-0094.wav - Median RMS energy: 0.09770478308200836
# File: LJ001-0078.wav - Median RMS energy: 0.10982443392276764
# File: LJ002-0075.wav - Median RMS energy: 0.10213743895292282
# File: LJ002-0039.wav - Median RMS energy: 0.09630021452903748
# File: LJ002-0013.wav - Median RMS energy: 0.09502153098583221
# File: LJ003-0001.wav - Median RMS energy: 0.078889399766922
# File: LJ002-0098.wav - Median RMS energy: 0.10025131702423096
# File: LJ002-0026.wav - Median RMS energy: 0.08127990365028381
# File: LJ002-0078.wav - Median RMS energy: 0.09022018313407898
# File: LJ001-0032.wav - Median RMS energy: 0.09051262587308884
# File: LJ003-0318.wav - Median RMS energy: 0.08805350959300995
# File: LJ003-0199.wav - Median RMS energy: 0.09762595593929291
# File: LJ003-0099.wav - Median RMS energy: 0.07015609741210938
# File: LJ001-0155.wav - Median RMS energy: 0.09162114560604095
# File: LJ002-0279.wav - Median RMS energy: 0.08326804637908936
# File: LJ002-0253.wav - Median RMS energy: 0.07069578766822815
# File: LJ002-0113.wav - Median RMS energy: 0.06379251927137375
# File: LJ003-0134.wav - Median RMS energy: 0.08064094930887222
# File: LJ002-0167.wav - Median RMS energy: 0.10556873679161072
# File: LJ004-0012.wav - Median RMS energy: 0.1248881071805954
# File: LJ002-0248.wav - Median RMS energy: 0.08611740916967392
# File: LJ003-0347.wav - Median RMS energy: 0.10337142646312714
# File: LJ003-0263.wav - Median RMS energy: 0.08215835690498352
# File: LJ003-0161.wav - Median RMS energy: 0.07462531328201294
# File: LJ002-0273.wav - Median RMS energy: 0.09893561154603958
# File: LJ003-0076.wav - Median RMS energy: 0.10627296566963196
# File: LJ002-0159.wav - Median RMS energy: 0.09170961380004883
# File: LJ002-0185.wav - Median RMS energy: 0.08587473630905151
# File: LJ001-0054.wav - Median RMS energy: 0.07598195970058441
# File: LJ002-0165.wav - Median RMS energy: 0.062258508056402206
# File: LJ002-0135.wav - Median RMS energy: 0.09248912334442139
# File: LJ002-0023.wav - Median RMS energy: 0.09180109947919846
# File: LJ002-0309.wav - Median RMS energy: 0.06853029131889343
# File: LJ003-0152.wav - Median RMS energy: 0.07469674944877625
# File: LJ002-0060.wav - Median RMS energy: 0.08141186833381653
# File: LJ004-0008.wav - Median RMS energy: 0.1187155693769455
# File: LJ001-0094.wav - Median RMS energy: 0.10280114412307739
# File: LJ002-0084.wav - Median RMS energy: 0.0940089151263237
# File: LJ002-0216.wav - Median RMS energy: 0.08458441495895386
# File: LJ003-0304.wav - Median RMS energy: 0.07613222301006317
# File: LJ003-0008.wav - Median RMS energy: 0.08462730050086975
# File: LJ002-0040.wav - Median RMS energy: 0.06338825076818466
# File: LJ002-0162.wav - Median RMS energy: 0.11541441082954407
# File: LJ003-0271.wav - Median RMS energy: 0.10915011167526245
# File: LJ002-0037.wav - Median RMS energy: 0.10245984047651291
# File: LJ002-0046.wav - Median RMS energy: 0.08879213035106659
# File: LJ003-0207.wav - Median RMS energy: 0.09734636545181274
# File: LJ003-0130.wav - Median RMS energy: 0.10731178522109985
# File: LJ003-0301.wav - Median RMS energy: 0.09440834820270538
# File: LJ002-0112.wav - Median RMS energy: 0.11119338124990463
# File: LJ003-0042.wav - Median RMS energy: 0.06881009787321091
# File: LJ003-0284.wav - Median RMS energy: 0.10203029215335846
# File: LJ002-0225.wav - Median RMS energy: 0.09624321013689041
# File: LJ003-0133.wav - Median RMS energy: 0.09588148444890976
# File: LJ002-0114.wav - Median RMS energy: 0.09872578829526901
# File: LJ002-0247.wav - Median RMS energy: 0.07289297878742218
# File: LJ001-0043.wav - Median RMS energy: 0.09631345421075821
# File: LJ002-0184.wav - Median RMS energy: 0.07902631908655167
# File: LJ001-0053.wav - Median RMS energy: 0.09312745183706284
# File: LJ002-0171.wav - Median RMS energy: 0.08611498773097992
# File: LJ003-0039.wav - Median RMS energy: 0.09901444613933563
# File: LJ003-0302.wav - Median RMS energy: 0.11551627516746521
# File: LJ003-0025.wav - Median RMS energy: 0.08705992996692657
# File: LJ002-0242.wav - Median RMS energy: 0.09088598191738129
# File: LJ002-0214.wav - Median RMS energy: 0.09221858531236649
# File: LJ001-0097.wav - Median RMS energy: 0.0893186628818512
# File: LJ001-0072.wav - Median RMS energy: 0.08328877389431
# File: LJ003-0277.wav - Median RMS energy: 0.08303246647119522
# File: LJ003-0320.wav - Median RMS energy: 0.1296842396259308
# File: LJ002-0311.wav - Median RMS energy: 0.11751285195350647
# File: LJ002-0336.wav - Median RMS energy: 0.07557982206344604
# File: LJ003-0172.wav - Median RMS energy: 0.11117170751094818
# File: LJ002-0079.wav - Median RMS energy: 0.06776079535484314
# File: LJ002-0094.wav - Median RMS energy: 0.0725896954536438
# File: LJ004-0005.wav - Median RMS energy: 0.10158151388168335
# File: LJ003-0020.wav - Median RMS energy: 0.10811489820480347
# File: LJ002-0052.wav - Median RMS energy: 0.07239431887865067
# File: LJ001-0019.wav - Median RMS energy: 0.08061287552118301
# File: LJ003-0112.wav - Median RMS energy: 0.11454788595438004
# File: LJ001-0001.wav - Median RMS energy: 0.08603335916996002
# File: LJ004-0018.wav - Median RMS energy: 0.09444601833820343
# File: LJ002-0010.wav - Median RMS energy: 0.09156735986471176
# File: LJ001-0099.wav - Median RMS energy: 0.0918721929192543
# File: LJ002-0128.wav - Median RMS energy: 0.08289168030023575
# File: LJ003-0127.wav - Median RMS energy: 0.10956469178199768
# File: LJ003-0150.wav - Median RMS energy: 0.08403553068637848
# File: LJ001-0089.wav - Median RMS energy: 0.08288729190826416
# File: LJ001-0049.wav - Median RMS energy: 0.0891406387090683
# File: LJ002-0020.wav - Median RMS energy: 0.0723855048418045
# File: LJ002-0100.wav - Median RMS energy: 0.080935537815094
# File: LJ003-0344.wav - Median RMS energy: 0.09352799504995346
# File: LJ001-0012.wav - Median RMS energy: 0.08713740110397339
# File: LJ002-0104.wav - Median RMS energy: 0.09660257399082184
# File: LJ001-0073.wav - Median RMS energy: 0.09681003540754318
# File: LJ003-0291.wav - Median RMS energy: 0.09784764796495438
# File: LJ003-0181.wav - Median RMS energy: 0.09818548709154129
# File: LJ002-0307.wav - Median RMS energy: 0.11591428518295288
# File: LJ003-0176.wav - Median RMS energy: 0.11234380304813385
# File: LJ003-0116.wav - Median RMS energy: 0.07934051007032394
# File: LJ003-0038.wav - Median RMS energy: 0.09360754489898682
# File: LJ003-0321.wav - Median RMS energy: 0.13394254446029663
# File: LJ002-0305.wav - Median RMS energy: 0.0812695249915123
# File: LJ003-0327.wav - Median RMS energy: 0.09518389403820038
# File: LJ001-0027.wav - Median RMS energy: 0.10692214965820312
# File: LJ003-0194.wav - Median RMS energy: 0.09587490558624268
# File: LJ003-0051.wav - Median RMS energy: 0.0769423320889473
# File: LJ002-0272.wav - Median RMS energy: 0.08267854154109955
# File: LJ002-0281.wav - Median RMS energy: 0.053961947560310364
# File: LJ004-0014.wav - Median RMS energy: 0.08354080468416214
# File: LJ003-0288.wav - Median RMS energy: 0.09360376745462418
# File: LJ003-0235.wav - Median RMS energy: 0.08574239909648895
# File: LJ002-0262.wav - Median RMS energy: 0.0909443348646164
# File: LJ001-0020.wav - Median RMS energy: 0.0998401939868927
# File: LJ002-0285.wav - Median RMS energy: 0.09802446514368057
# File: LJ002-0289.wav - Median RMS energy: 0.11836865544319153
# File: LJ002-0012.wav - Median RMS energy: 0.1105203852057457
# File: LJ002-0329.wav - Median RMS energy: 0.08796899020671844
# File: LJ002-0268.wav - Median RMS energy: 0.09743192791938782
# File: LJ001-0154.wav - Median RMS energy: 0.11126704514026642
# File: LJ003-0032.wav - Median RMS energy: 0.1001104786992073
# File: LJ002-0048.wav - Median RMS energy: 0.08671168982982635
# File: LJ004-0020.wav - Median RMS energy: 0.1156855970621109
# File: LJ002-0278.wav - Median RMS energy: 0.08964037150144577
# File: LJ001-0119.wav - Median RMS energy: 0.08063095062971115
# File: LJ004-0003.wav - Median RMS energy: 0.07678476721048355
# File: LJ003-0340.wav - Median RMS energy: 0.07696695625782013
# File: LJ003-0048.wav - Median RMS energy: 0.10359679907560349
# File: LJ003-0224.wav - Median RMS energy: 0.0961381047964096
# File: LJ003-0312.wav - Median RMS energy: 0.09236621111631393
# File: LJ001-0018.wav - Median RMS energy: 0.09788290411233902
# File: LJ003-0337.wav - Median RMS energy: 0.09841857850551605
# File: LJ003-0052.wav - Median RMS energy: 0.09806450456380844
# File: LJ001-0134.wav - Median RMS energy: 0.10059858858585358
# File: LJ003-0108.wav - Median RMS energy: 0.1068858802318573
# File: LJ002-0304.wav - Median RMS energy: 0.08352820575237274
# File: LJ003-0200.wav - Median RMS energy: 0.11134514957666397
# File: LJ001-0133.wav - Median RMS energy: 0.08955209702253342
# File: LJ004-0021.wav - Median RMS energy: 0.10092689096927643
# File: LJ002-0047.wav - Median RMS energy: 0.09316040575504303
# File: LJ001-0114.wav - Median RMS energy: 0.0879516750574112
# File: LJ001-0169.wav - Median RMS energy: 0.10987728089094162
# File: LJ003-0297.wav - Median RMS energy: 0.06536785513162613
# File: LJ003-0201.wav - Median RMS energy: 0.08443182706832886
# File: LJ003-0249.wav - Median RMS energy: 0.08596298098564148
# File: LJ002-0235.wav - Median RMS energy: 0.10287473350763321
# File: LJ002-0134.wav - Median RMS energy: 0.09165632724761963
# File: LJ002-0333.wav - Median RMS energy: 0.08838391304016113
# File: LJ003-0146.wav - Median RMS energy: 0.09573124349117279
# File: LJ002-0172.wav - Median RMS energy: 0.09659343957901001
# File: LJ003-0308.wav - Median RMS energy: 0.09665799140930176
# File: LJ002-0168.wav - Median RMS energy: 0.09573231637477875
# File: LJ003-0306.wav - Median RMS energy: 0.10827255249023438
# File: LJ003-0075.wav - Median RMS energy: 0.09560961276292801
# File: LJ002-0136.wav - Median RMS energy: 0.05815720930695534
# File: LJ003-0103.wav - Median RMS energy: 0.09450143575668335
# File: LJ002-0001.wav - Median RMS energy: 0.07951800525188446
# File: LJ001-0042.wav - Median RMS energy: 0.10218259692192078
# File: LJ003-0279.wav - Median RMS energy: 0.07179328799247742
# File: LJ002-0061.wav - Median RMS energy: 0.08085310459136963
# File: LJ003-0267.wav - Median RMS energy: 0.11013926565647125
# File: LJ003-0109.wav - Median RMS energy: 0.12095755338668823
# File: LJ003-0030.wav - Median RMS energy: 0.09610791504383087
# File: LJ001-0127.wav - Median RMS energy: 0.09894807636737823
# File: LJ002-0295.wav - Median RMS energy: 0.09738857299089432
# File: LJ004-0023.wav - Median RMS energy: 0.08682496845722198
# File: LJ002-0220.wav - Median RMS energy: 0.08412127941846848
# File: LJ002-0301.wav - Median RMS energy: 0.09810595959424973
# File: LJ001-0087.wav - Median RMS energy: 0.08915139734745026
# File: LJ001-0013.wav - Median RMS energy: 0.09356505423784256
# File: LJ003-0346.wav - Median RMS energy: 0.09262365102767944
# File: LJ003-0183.wav - Median RMS energy: 0.08824686706066132
# File: LJ003-0209.wav - Median RMS energy: 0.11763504892587662
# File: LJ002-0288.wav - Median RMS energy: 0.1249191090464592
# File: LJ002-0293.wav - Median RMS energy: 0.08237936347723007
# File: LJ002-0312.wav - Median RMS energy: 0.10645152628421783
# File: LJ003-0231.wav - Median RMS energy: 0.08625926822423935
# File: LJ001-0017.wav - Median RMS energy: 0.08820706605911255
# File: LJ001-0141.wav - Median RMS energy: 0.07934834063053131
# File: LJ002-0237.wav - Median RMS energy: 0.09823183715343475
# File: LJ003-0118.wav - Median RMS energy: 0.10338693112134933
# File: LJ002-0202.wav - Median RMS energy: 0.11522231251001358
# File: LJ001-0126.wav - Median RMS energy: 0.12109342962503433
# File: LJ003-0119.wav - Median RMS energy: 0.089971624314785
# File: LJ003-0167.wav - Median RMS energy: 0.10389486700296402
# File: LJ003-0253.wav - Median RMS energy: 0.09076111018657684
# File: LJ002-0140.wav - Median RMS energy: 0.110006183385849
# File: LJ002-0294.wav - Median RMS energy: 0.0717754140496254
# File: LJ003-0041.wav - Median RMS energy: 0.09564520418643951
# File: LJ002-0055.wav - Median RMS energy: 0.07988542318344116
# File: LJ001-0124.wav - Median RMS energy: 0.09238046407699585
# File: LJ001-0002.wav - Median RMS energy: 0.0963967964053154
# File: LJ003-0226.wav - Median RMS energy: 0.11623552441596985
# File: LJ003-0179.wav - Median RMS energy: 0.08655047416687012
# File: LJ003-0093.wav - Median RMS energy: 0.07936599105596542
# File: LJ002-0087.wav - Median RMS energy: 0.08234073966741562
# File: LJ002-0083.wav - Median RMS energy: 0.11196558177471161
# File: LJ001-0046.wav - Median RMS energy: 0.09522591531276703
# File: LJ002-0119.wav - Median RMS energy: 0.10607916116714478
# File: LJ002-0038.wav - Median RMS energy: 0.08978872001171112
# File: LJ002-0308.wav - Median RMS energy: 0.09483747184276581
# File: LJ001-0128.wav - Median RMS energy: 0.10209094732999802
# File: LJ002-0334.wav - Median RMS energy: 0.09062398970127106
# File: LJ003-0222.wav - Median RMS energy: 0.08601557463407516
# File: LJ003-0128.wav - Median RMS energy: 0.09749965369701385
# File: LJ003-0077.wav - Median RMS energy: 0.09581409394741058
# File: LJ003-0217.wav - Median RMS energy: 0.09183062613010406
# File: LJ003-0169.wav - Median RMS energy: 0.08508330583572388
# File: LJ002-0275.wav - Median RMS energy: 0.08368828892707825
# File: LJ002-0081.wav - Median RMS energy: 0.09294277429580688
# File: LJ002-0226.wav - Median RMS energy: 0.10197919607162476
# File: LJ001-0156.wav - Median RMS energy: 0.1109912171959877
# File: LJ002-0302.wav - Median RMS energy: 0.0714447870850563
# File: LJ001-0093.wav - Median RMS energy: 0.08768713474273682
# File: LJ002-0209.wav - Median RMS energy: 0.09475959837436676
# File: LJ003-0186.wav - Median RMS energy: 0.09361642599105835
# File: LJ001-0039.wav - Median RMS energy: 0.07605461776256561
# File: LJ001-0121.wav - Median RMS energy: 0.0935724526643753
# File: LJ002-0129.wav - Median RMS energy: 0.09669487923383713
# File: LJ003-0275.wav - Median RMS energy: 0.08388275653123856
# File: LJ002-0043.wav - Median RMS energy: 0.09806208312511444
# File: LJ003-0197.wav - Median RMS energy: 0.09957390278577805
# File: LJ003-0043.wav - Median RMS energy: 0.10913608968257904
# File: LJ002-0206.wav - Median RMS energy: 0.08470897376537323
# File: LJ002-0244.wav - Median RMS energy: 0.07267964631319046
# File: LJ003-0242.wav - Median RMS energy: 0.07688775658607483
# File: LJ002-0241.wav - Median RMS energy: 0.08139315247535706
# File: LJ002-0256.wav - Median RMS energy: 0.08412016928195953
# File: LJ002-0042.wav - Median RMS energy: 0.09299280494451523
# File: LJ002-0316.wav - Median RMS energy: 0.08956395089626312
# File: LJ002-0141.wav - Median RMS energy: 0.09649591147899628
# File: LJ002-0245.wav - Median RMS energy: 0.06662796437740326
# File: LJ003-0332.wav - Median RMS energy: 0.09127959609031677
# File: LJ004-0013.wav - Median RMS energy: 0.10372588783502579
# File: LJ003-0110.wav - Median RMS energy: 0.08933036774396896
# File: LJ003-0139.wav - Median RMS energy: 0.10944616049528122
# File: LJ002-0030.wav - Median RMS energy: 0.09225531667470932
# File: LJ004-0016.wav - Median RMS energy: 0.0902130976319313
# File: LJ003-0011.wav - Median RMS energy: 0.08865565061569214
# File: LJ001-0180.wav - Median RMS energy: 0.0757661908864975
# File: LJ002-0322.wav - Median RMS energy: 0.08792492002248764
# File: LJ003-0148.wav - Median RMS energy: 0.09821493923664093
# File: LJ002-0059.wav - Median RMS energy: 0.08900780975818634
# File: LJ003-0046.wav - Median RMS energy: 0.11538264900445938
# File: LJ002-0252.wav - Median RMS energy: 0.1197856143116951
# File: LJ002-0139.wav - Median RMS energy: 0.09456653147935867
# File: LJ002-0035.wav - Median RMS energy: 0.052892643958330154
# File: LJ002-0192.wav - Median RMS energy: 0.09063471108675003
# File: LJ003-0214.wav - Median RMS energy: 0.09197329729795456
# File: LJ002-0190.wav - Median RMS energy: 0.0786634162068367
# File: LJ002-0160.wav - Median RMS energy: 0.07896494120359421
# File: LJ001-0091.wav - Median RMS energy: 0.08658900856971741
# File: LJ002-0264.wav - Median RMS energy: 0.1007118821144104
# File: LJ002-0007.wav - Median RMS energy: 0.09251870959997177
# File: LJ001-0170.wav - Median RMS energy: 0.07929521054029465
# File: LJ003-0303.wav - Median RMS energy: 0.10230906307697296
# File: LJ003-0065.wav - Median RMS energy: 0.10553126037120819
# File: LJ003-0017.wav - Median RMS energy: 0.09880902618169785
# File: LJ001-0075.wav - Median RMS energy: 0.09796696156263351
# File: LJ003-0325.wav - Median RMS energy: 0.0867769718170166
# File: LJ001-0096.wav - Median RMS energy: 0.0976206511259079
# File: LJ002-0261.wav - Median RMS energy: 0.08706820756196976
# File: LJ003-0131.wav - Median RMS energy: 0.10775802284479141
# File: LJ003-0107.wav - Median RMS energy: 0.08180807530879974
# File: LJ002-0257.wav - Median RMS energy: 0.10007723420858383
# File: LJ001-0146.wav - Median RMS energy: 0.09418369084596634
# File: LJ002-0067.wav - Median RMS energy: 0.08137767761945724
# File: LJ003-0229.wav - Median RMS energy: 0.09725801646709442
# File: LJ003-0184.wav - Median RMS energy: 0.08040539175271988
# File: LJ003-0254.wav - Median RMS energy: 0.08103330433368683
# File: LJ003-0104.wav - Median RMS energy: 0.09289242327213287
# File: LJ003-0250.wav - Median RMS energy: 0.07661879062652588
# File: LJ003-0237.wav - Median RMS energy: 0.11443056911230087
# File: LJ001-0070.wav - Median RMS energy: 0.10191945731639862
# File: LJ003-0096.wav - Median RMS energy: 0.10909797251224518
# File: LJ002-0009.wav - Median RMS energy: 0.10967260599136353
# File: LJ002-0090.wav - Median RMS energy: 0.10806449502706528
# File: LJ003-0049.wav - Median RMS energy: 0.09100737422704697
# File: LJ003-0141.wav - Median RMS energy: 0.0967458188533783
# File: LJ002-0217.wav - Median RMS energy: 0.08240818232297897
# File: LJ003-0230.wav - Median RMS energy: 0.10378848016262054
# File: LJ001-0129.wav - Median RMS energy: 0.09179504215717316
# File: LJ002-0101.wav - Median RMS energy: 0.08825084567070007
# File: LJ003-0290.wav - Median RMS energy: 0.11044099926948547
# File: LJ003-0070.wav - Median RMS energy: 0.0988118126988411
# File: LJ002-0054.wav - Median RMS energy: 0.10759555548429489
# File: LJ003-0338.wav - Median RMS energy: 0.0951763316988945
# File: LJ003-0345.wav - Median RMS energy: 0.0914354920387268
# File: LJ001-0061.wav - Median RMS energy: 0.0919472724199295
# File: LJ002-0041.wav - Median RMS energy: 0.10235323011875153
# File: LJ001-0011.wav - Median RMS energy: 0.10454175621271133
# File: LJ002-0177.wav - Median RMS energy: 0.09137717634439468
# File: LJ003-0079.wav - Median RMS energy: 0.09881752729415894
# File: LJ001-0120.wav - Median RMS energy: 0.11764926463365555
# File: LJ003-0162.wav - Median RMS energy: 0.09985728561878204
# File: LJ003-0225.wav - Median RMS energy: 0.09309177100658417
# File: LJ002-0219.wav - Median RMS energy: 0.09734835475683212
# File: LJ003-0241.wav - Median RMS energy: 0.07685064524412155
# File: LJ003-0068.wav - Median RMS energy: 0.09614252299070358
# File: LJ003-0247.wav - Median RMS energy: 0.0868801400065422
# File: LJ003-0261.wav - Median RMS energy: 0.08816704154014587
# File: LJ001-0115.wav - Median RMS energy: 0.10216320306062698
# File: LJ003-0287.wav - Median RMS energy: 0.07245148718357086
# File: LJ002-0018.wav - Median RMS energy: 0.08338120579719543
# File: LJ003-0064.wav - Median RMS energy: 0.12475507706403732
# File: LJ003-0228.wav - Median RMS energy: 0.05925274267792702
# File: LJ003-0066.wav - Median RMS energy: 0.09091656655073166
# File: LJ002-0004.wav - Median RMS energy: 0.07883511483669281
# File: LJ001-0098.wav - Median RMS energy: 0.07710923999547958
# File: LJ003-0349.wav - Median RMS energy: 0.10242954641580582
# File: LJ003-0147.wav - Median RMS energy: 0.07862873375415802
# File: LJ002-0298.wav - Median RMS energy: 0.11451290547847748
# File: LJ003-0016.wav - Median RMS energy: 0.08830884844064713
# File: LJ003-0259.wav - Median RMS energy: 0.11435583233833313
# File: LJ003-0031.wav - Median RMS energy: 0.07655500620603561
# File: LJ003-0055.wav - Median RMS energy: 0.08216482400894165
# File: LJ003-0171.wav - Median RMS energy: 0.08413182199001312
# File: LJ001-0003.wav - Median RMS energy: 0.08711300790309906
# File: LJ002-0331.wav - Median RMS energy: 0.08957181870937347
# File: LJ002-0108.wav - Median RMS energy: 0.07309029996395111
# File: LJ003-0004.wav - Median RMS energy: 0.10647187381982803
# File: LJ003-0311.wav - Median RMS energy: 0.09273458272218704
# File: LJ003-0339.wav - Median RMS energy: 0.10170173645019531
# File: LJ001-0031.wav - Median RMS energy: 0.09913287311792374
# File: LJ003-0244.wav - Median RMS energy: 0.08625949174165726
# File: LJ003-0036.wav - Median RMS energy: 0.06956950575113297
# File: LJ003-0132.wav - Median RMS energy: 0.08611415326595306
# File: LJ003-0309.wav - Median RMS energy: 0.12885257601737976
# File: LJ002-0153.wav - Median RMS energy: 0.07271945476531982
# File: LJ003-0294.wav - Median RMS energy: 0.07932813465595245
# File: LJ003-0322.wav - Median RMS energy: 0.10353288799524307
# File: LJ003-0135.wav - Median RMS energy: 0.10923799872398376
# File: LJ001-0111.wav - Median RMS energy: 0.1062462106347084
# File: LJ001-0047.wav - Median RMS energy: 0.08316311985254288
# File: LJ002-0254.wav - Median RMS energy: 0.08203639835119247
# File: LJ002-0127.wav - Median RMS energy: 0.08700799942016602
# File: LJ002-0321.wav - Median RMS energy: 0.08238071948289871
# File: LJ003-0203.wav - Median RMS energy: 0.1011987030506134
# File: LJ003-0081.wav - Median RMS energy: 0.11399000883102417
# File: LJ001-0142.wav - Median RMS energy: 0.1262330710887909
# File: LJ003-0269.wav - Median RMS energy: 0.08158359676599503
# File: LJ002-0077.wav - Median RMS energy: 0.08853835612535477
# File: LJ003-0125.wav - Median RMS energy: 0.07386999577283859
# File: LJ001-0077.wav - Median RMS energy: 0.08425112068653107
# File: LJ002-0099.wav - Median RMS energy: 0.09456323832273483
# File: LJ001-0173.wav - Median RMS energy: 0.1011316329240799
# File: LJ004-0004.wav - Median RMS energy: 0.07361418753862381
# File: LJ003-0071.wav - Median RMS energy: 0.092379130423069
# File: LJ002-0170.wav - Median RMS energy: 0.09542912244796753
# File: LJ002-0183.wav - Median RMS energy: 0.09900294989347458
# File: LJ003-0317.wav - Median RMS energy: 0.10439232736825943
# File: LJ002-0073.wav - Median RMS energy: 0.10102950781583786
# File: LJ003-0264.wav - Median RMS energy: 0.08334074169397354
# File: LJ002-0175.wav - Median RMS energy: 0.09212387353181839
# File: LJ001-0059.wav - Median RMS energy: 0.1040065661072731
# File: LJ001-0029.wav - Median RMS energy: 0.08625263720750809
# File: LJ003-0163.wav - Median RMS energy: 0.07837043702602386
# File: LJ003-0246.wav - Median RMS energy: 0.09091337025165558
# File: LJ002-0260.wav - Median RMS energy: 0.09619583934545517
# File: LJ003-0180.wav - Median RMS energy: 0.11168073117733002
# File: LJ002-0221.wav - Median RMS energy: 0.09795018285512924
# File: LJ003-0298.wav - Median RMS energy: 0.08763489872217178
# File: LJ003-0138.wav - Median RMS energy: 0.10447300970554352
# File: LJ001-0183.wav - Median RMS energy: 0.08597159385681152
# File: LJ002-0085.wav - Median RMS energy: 0.08481775224208832
# File: LJ003-0326.wav - Median RMS energy: 0.09005964547395706
# File: LJ002-0131.wav - Median RMS energy: 0.09370595216751099
# File: LJ003-0213.wav - Median RMS energy: 0.11153285205364227
# File: LJ003-0177.wav - Median RMS energy: 0.06756425648927689
# File: LJ003-0021.wav - Median RMS energy: 0.09448447078466415
# File: LJ003-0314.wav - Median RMS energy: 0.08410722017288208
# File: LJ003-0023.wav - Median RMS energy: 0.0948033332824707
# File: LJ002-0315.wav - Median RMS energy: 0.0843317061662674
# File: LJ003-0053.wav - Median RMS energy: 0.09006659686565399
# File: LJ002-0157.wav - Median RMS energy: 0.09584931284189224
# File: LJ003-0095.wav - Median RMS energy: 0.1025281623005867
# File: LJ003-0193.wav - Median RMS energy: 0.10023244470357895
# File: LJ003-0044.wav - Median RMS energy: 0.10402154922485352
# File: LJ003-0218.wav - Median RMS energy: 0.08284974843263626
# File: LJ002-0151.wav - Median RMS energy: 0.08731593191623688
# File: LJ002-0197.wav - Median RMS energy: 0.07988075911998749
# File: LJ003-0154.wav - Median RMS energy: 0.08482254296541214
# File: LJ003-0165.wav - Median RMS energy: 0.11901959031820297
# File: LJ002-0327.wav - Median RMS energy: 0.09808427840471268
# File: LJ002-0032.wav - Median RMS energy: 0.09947338700294495
# File: LJ002-0224.wav - Median RMS energy: 0.10946542769670486
# File: LJ002-0292.wav - Median RMS energy: 0.09206535667181015
# File: LJ002-0008.wav - Median RMS energy: 0.10640798509120941
# File: LJ003-0129.wav - Median RMS energy: 0.07513870298862457
# File: LJ003-0245.wav - Median RMS energy: 0.08848533034324646
# File: LJ002-0234.wav - Median RMS energy: 0.08231086283922195
# File: LJ003-0185.wav - Median RMS energy: 0.08902187645435333
# File: LJ002-0126.wav - Median RMS energy: 0.09536013007164001
# File: LJ002-0255.wav - Median RMS energy: 0.09865157306194305
# File: LJ003-0324.wav - Median RMS energy: 0.10239087045192719
# File: LJ003-0115.wav - Median RMS energy: 0.08493493497371674
# File: LJ003-0153.wav - Median RMS energy: 0.08896644413471222
# File: LJ002-0044.wav - Median RMS energy: 0.07925163209438324
# File: LJ001-0175.wav - Median RMS energy: 0.09901687502861023
# File: LJ003-0343.wav - Median RMS energy: 0.07435962557792664
# File: LJ002-0212.wav - Median RMS energy: 0.07069915533065796
# File: LJ001-0068.wav - Median RMS energy: 0.0965704619884491
# File: LJ001-0092.wav - Median RMS energy: 0.10649707168340683
# File: LJ003-0170.wav - Median RMS energy: 0.09973084926605225
# File: LJ002-0230.wav - Median RMS energy: 0.09128376841545105
# File: LJ003-0037.wav - Median RMS energy: 0.09177601337432861
# File: LJ003-0159.wav - Median RMS energy: 0.0996956005692482
# File: LJ001-0147.wav - Median RMS energy: 0.09860976785421371
# File: LJ003-0002.wav - Median RMS energy: 0.09450392425060272
# File: LJ002-0122.wav - Median RMS energy: 0.08642791211605072
# File: LJ003-0265.wav - Median RMS energy: 0.08549097180366516
# File: LJ002-0290.wav - Median RMS energy: 0.08274687826633453
# File: LJ001-0159.wav - Median RMS energy: 0.10137622803449631
# File: LJ001-0008.wav - Median RMS energy: 0.09702073037624359
# File: LJ001-0166.wav - Median RMS energy: 0.08673050999641418
# File: LJ003-0305.wav - Median RMS energy: 0.09355250746011734
# File: LJ003-0316.wav - Median RMS energy: 0.09901590645313263
# File: LJ003-0212.wav - Median RMS energy: 0.07474387437105179
# File: LJ002-0324.wav - Median RMS energy: 0.08263237774372101
# File: LJ003-0121.wav - Median RMS energy: 0.0974498838186264
# File: LJ002-0091.wav - Median RMS energy: 0.10377471148967743
# File: LJ001-0117.wav - Median RMS energy: 0.08099512755870819
# File: LJ002-0176.wav - Median RMS energy: 0.09312939643859863
# File: LJ003-0097.wav - Median RMS energy: 0.10402688384056091
# File: LJ002-0088.wav - Median RMS energy: 0.0939396321773529
# File: LJ002-0231.wav - Median RMS energy: 0.0847279354929924
# File: LJ002-0291.wav - Median RMS energy: 0.1050613597035408
# File: LJ001-0110.wav - Median RMS energy: 0.09508354216814041
# File: LJ001-0014.wav - Median RMS energy: 0.0909622386097908
# File: LJ003-0331.wav - Median RMS energy: 0.09791380167007446
# File: LJ002-0330.wav - Median RMS energy: 0.09233321994543076
# File: LJ001-0148.wav - Median RMS energy: 0.11373024433851242
# File: LJ002-0148.wav - Median RMS energy: 0.07739301025867462
# File: LJ002-0015.wav - Median RMS energy: 0.1081729307770729
# File: LJ001-0122.wav - Median RMS energy: 0.09386332333087921
# File: LJ002-0233.wav - Median RMS energy: 0.10841844975948334
# File: LJ002-0240.wav - Median RMS energy: 0.09596739709377289
# File: LJ001-0016.wav - Median RMS energy: 0.08484064787626266
# File: LJ002-0276.wav - Median RMS energy: 0.10841496288776398
# File: LJ003-0192.wav - Median RMS energy: 0.0979170948266983
# File: LJ002-0280.wav - Median RMS energy: 0.08859793841838837
# File: LJ003-0240.wav - Median RMS energy: 0.09203869849443436
# File: LJ004-0006.wav - Median RMS energy: 0.10673859715461731
# File: LJ002-0028.wav - Median RMS energy: 0.10223539918661118
# File: LJ002-0238.wav - Median RMS energy: 0.09959697723388672
# File: LJ002-0069.wav - Median RMS energy: 0.06797104328870773
# File: LJ002-0109.wav - Median RMS energy: 0.0934956818819046
# File: LJ003-0003.wav - Median RMS energy: 0.0964500680565834
# File: LJ003-0232.wav - Median RMS energy: 0.10083115100860596
# File: LJ003-0072.wav - Median RMS energy: 0.09081355482339859
# File: LJ002-0182.wav - Median RMS energy: 0.09185122698545456
# File: LJ002-0164.wav - Median RMS energy: 0.09405766427516937
# File: LJ002-0158.wav - Median RMS energy: 0.10625801235437393
# File: LJ002-0187.wav - Median RMS energy: 0.0864168256521225
# File: LJ002-0269.wav - Median RMS energy: 0.11281132698059082
# File: LJ001-0058.wav - Median RMS energy: 0.08836778253316879
# File: LJ001-0107.wav - Median RMS energy: 0.1099119484424591
# File: LJ002-0095.wav - Median RMS energy: 0.06583049148321152
# File: LJ001-0085.wav - Median RMS energy: 0.0957423746585846
# File: LJ003-0035.wav - Median RMS energy: 0.0815047174692154
# File: LJ002-0210.wav - Median RMS energy: 0.09759360551834106
# File: LJ003-0223.wav - Median RMS energy: 0.0851244181394577
# File: LJ003-0067.wav - Median RMS energy: 0.06748364120721817
# File: LJ002-0265.wav - Median RMS energy: 0.10118386149406433
# File: LJ002-0267.wav - Median RMS energy: 0.08412542939186096
# File: LJ003-0341.wav - Median RMS energy: 0.09645120054483414
# File: LJ001-0123.wav - Median RMS energy: 0.0929846242070198
# File: LJ003-0248.wav - Median RMS energy: 0.07996811717748642
# File: LJ002-0116.wav - Median RMS energy: 0.09162253886461258
# File: LJ003-0198.wav - Median RMS energy: 0.1014523059129715
# File: LJ002-0024.wav - Median RMS energy: 0.07431997358798981
# File: LJ002-0306.wav - Median RMS energy: 0.08713847398757935
# File: LJ002-0271.wav - Median RMS energy: 0.10174080729484558
# File: LJ002-0283.wav - Median RMS energy: 0.09450996667146683
# File: LJ002-0082.wav - Median RMS energy: 0.08305969834327698
# File: LJ002-0200.wav - Median RMS energy: 0.07717985659837723
# File: LJ002-0208.wav - Median RMS energy: 0.09461996704339981
# File: LJ003-0280.wav - Median RMS energy: 0.07318925112485886
# File: LJ002-0097.wav - Median RMS energy: 0.097757488489151
# File: LJ002-0232.wav - Median RMS energy: 0.09286496043205261
# File: LJ001-0113.wav - Median RMS energy: 0.08341789245605469
# File: LJ002-0072.wav - Median RMS energy: 0.08419034630060196
# File: LJ002-0277.wav - Median RMS energy: 0.0813259705901146
# File: LJ003-0216.wav - Median RMS energy: 0.09235597401857376
# File: LJ001-0109.wav - Median RMS energy: 0.0965854749083519
# File: LJ003-0164.wav - Median RMS energy: 0.08901706337928772
# File: LJ002-0156.wav - Median RMS energy: 0.09233785420656204
# File: LJ001-0065.wav - Median RMS energy: 0.08964018523693085
# File: LJ001-0176.wav - Median RMS energy: 0.10073352605104446
# File: LJ001-0160.wav - Median RMS energy: 0.07775812596082687
# File: LJ003-0160.wav - Median RMS energy: 0.09195937216281891
# File: LJ002-0120.wav - Median RMS energy: 0.08940893411636353
# File: LJ001-0007.wav - Median RMS energy: 0.1134067103266716
# File: LJ001-0137.wav - Median RMS energy: 0.08645181357860565
# File: LJ001-0056.wav - Median RMS energy: 0.09377272427082062
# File: LJ001-0015.wav - Median RMS energy: 0.10758942365646362
# File: LJ001-0048.wav - Median RMS energy: 0.10348684340715408
# File: LJ003-0260.wav - Median RMS energy: 0.07585671544075012
# File: LJ003-0106.wav - Median RMS energy: 0.06921617686748505
# File: LJ003-0329.wav - Median RMS energy: 0.11295093595981598
# File: LJ003-0092.wav - Median RMS energy: 0.09362642467021942
# File: LJ003-0142.wav - Median RMS energy: 0.11228611320257187
# File: LJ003-0283.wav - Median RMS energy: 0.08995959162712097
# File: LJ001-0050.wav - Median RMS energy: 0.08486712723970413
# File: LJ003-0310.wav - Median RMS energy: 0.0889751985669136
# File: LJ003-0026.wav - Median RMS energy: 0.0910433754324913
# File: LJ001-0118.wav - Median RMS energy: 0.08693867921829224
# File: LJ002-0337.wav - Median RMS energy: 0.09895312786102295
# File: LJ002-0199.wav - Median RMS energy: 0.07208951562643051
# File: LJ005-0032.wav - Median RMS energy: 0.09817858040332794
# File: LJ004-0182.wav - Median RMS energy: 0.09011255204677582
# File: LJ004-0228.wav - Median RMS energy: 0.09956483542919159
# File: LJ004-0081.wav - Median RMS energy: 0.07683037966489792
# File: LJ004-0183.wav - Median RMS energy: 0.06817907094955444
# File: LJ004-0098.wav - Median RMS energy: 0.0871921107172966
# File: LJ005-0017.wav - Median RMS energy: 0.09159907698631287
# File: LJ004-0229.wav - Median RMS energy: 0.11511651426553726
# File: LJ004-0221.wav - Median RMS energy: 0.10456239432096481
# File: LJ004-0144.wav - Median RMS energy: 0.08083198219537735
# File: LJ004-0111.wav - Median RMS energy: 0.08919225633144379
# File: LJ004-0114.wav - Median RMS energy: 0.08713922649621964
# File: LJ005-0093.wav - Median RMS energy: 0.07979987561702728
# File: LJ004-0109.wav - Median RMS energy: 0.0725724846124649
# File: LJ005-0049.wav - Median RMS energy: 0.11123962700366974
# File: LJ004-0199.wav - Median RMS energy: 0.09686697274446487
# File: LJ004-0171.wav - Median RMS energy: 0.10286025702953339
# File: LJ005-0095.wav - Median RMS energy: 0.09725460410118103
# File: LJ004-0129.wav - Median RMS energy: 0.12317133694887161
# File: LJ004-0181.wav - Median RMS energy: 0.08569573611021042
# File: LJ004-0233.wav - Median RMS energy: 0.10044798254966736
# File: LJ004-0123.wav - Median RMS energy: 0.08113927394151688
# File: LJ004-0140.wav - Median RMS energy: 0.07240089029073715
# File: LJ005-0096.wav - Median RMS energy: 0.1100320890545845
# File: LJ004-0106.wav - Median RMS energy: 0.08549322187900543
# File: LJ005-0012.wav - Median RMS energy: 0.09740757197141647
# File: LJ004-0075.wav - Median RMS energy: 0.09985826164484024
# File: LJ005-0007.wav - Median RMS energy: 0.07218094170093536
# File: LJ004-0037.wav - Median RMS energy: 0.09256871044635773
# File: LJ005-0091.wav - Median RMS energy: 0.10238517820835114
# File: LJ004-0161.wav - Median RMS energy: 0.09702254831790924
# File: LJ004-0162.wav - Median RMS energy: 0.08330903947353363
# File: LJ004-0173.wav - Median RMS energy: 0.09133607894182205
# File: LJ005-0038.wav - Median RMS energy: 0.11110305786132812
# File: LJ005-0086.wav - Median RMS energy: 0.10011947154998779
# File: LJ004-0139.wav - Median RMS energy: 0.0939062312245369
# File: LJ005-0005.wav - Median RMS energy: 0.10545608401298523
# File: LJ005-0084.wav - Median RMS energy: 0.0934191644191742
# File: LJ004-0049.wav - Median RMS energy: 0.0832815170288086
# File: LJ005-0043.wav - Median RMS energy: 0.0829695463180542
# File: LJ004-0141.wav - Median RMS energy: 0.09031140804290771
# File: LJ004-0100.wav - Median RMS energy: 0.09569824486970901
# File: LJ005-0034.wav - Median RMS energy: 0.09593339264392853
# File: LJ005-0039.wav - Median RMS energy: 0.12474116683006287
# File: LJ004-0165.wav - Median RMS energy: 0.0852048322558403
# File: LJ004-0159.wav - Median RMS energy: 0.08525107800960541
# File: LJ004-0138.wav - Median RMS energy: 0.1313677281141281
# File: LJ005-0064.wav - Median RMS energy: 0.07993318140506744
# File: LJ005-0082.wav - Median RMS energy: 0.09453277289867401
# File: LJ004-0118.wav - Median RMS energy: 0.10139070451259613
# File: LJ004-0191.wav - Median RMS energy: 0.12987738847732544
# File: LJ005-0047.wav - Median RMS energy: 0.09218485653400421
# File: LJ004-0063.wav - Median RMS energy: 0.090842604637146
# File: LJ004-0079.wav - Median RMS energy: 0.09887159615755081
# File: LJ005-0041.wav - Median RMS energy: 0.09690849483013153
# File: LJ004-0169.wav - Median RMS energy: 0.08414152264595032
# File: LJ004-0208.wav - Median RMS energy: 0.10058622062206268
# File: LJ004-0146.wav - Median RMS energy: 0.07635264098644257
# File: LJ004-0036.wav - Median RMS energy: 0.08862286806106567
# File: LJ005-0060.wav - Median RMS energy: 0.10424965620040894
# File: LJ004-0224.wav - Median RMS energy: 0.0937347561120987
# File: LJ005-0018.wav - Median RMS energy: 0.10446710884571075
# File: LJ005-0075.wav - Median RMS energy: 0.08601192384958267
# File: LJ004-0130.wav - Median RMS energy: 0.09869507700204849
# File: LJ004-0178.wav - Median RMS energy: 0.10475975275039673
# File: LJ004-0083.wav - Median RMS energy: 0.08825571835041046
# File: LJ005-0059.wav - Median RMS energy: 0.09402204304933548
# File: LJ005-0013.wav - Median RMS energy: 0.10681504011154175
# File: LJ004-0160.wav - Median RMS energy: 0.07532962411642075
# File: LJ005-0031.wav - Median RMS energy: 0.10285305976867676
# File: LJ005-0073.wav - Median RMS energy: 0.1018139123916626
# File: LJ005-0011.wav - Median RMS energy: 0.08698674291372299
# File: LJ004-0196.wav - Median RMS energy: 0.10679443180561066
# File: LJ004-0195.wav - Median RMS energy: 0.10421548038721085
# File: LJ004-0101.wav - Median RMS energy: 0.11053986847400665
# File: LJ004-0136.wav - Median RMS energy: 0.09960996359586716
# File: LJ004-0064.wav - Median RMS energy: 0.09712651371955872
# File: LJ004-0084.wav - Median RMS energy: 0.08999519795179367
# File: LJ005-0094.wav - Median RMS energy: 0.07723957300186157
# File: LJ004-0174.wav - Median RMS energy: 0.07947706431150436
# File: LJ004-0179.wav - Median RMS energy: 0.0788632407784462
# File: LJ004-0041.wav - Median RMS energy: 0.09533117711544037
# File: LJ005-0061.wav - Median RMS energy: 0.09292317926883698
# File: LJ004-0189.wav - Median RMS energy: 0.09577445685863495
# File: LJ004-0074.wav - Median RMS energy: 0.09705865383148193
# File: LJ004-0216.wav - Median RMS energy: 0.0791742280125618
# File: LJ004-0150.wav - Median RMS energy: 0.09540687501430511
# File: LJ004-0030.wav - Median RMS energy: 0.0978899821639061
# File: LJ005-0025.wav - Median RMS energy: 0.1175614595413208
# File: LJ004-0077.wav - Median RMS energy: 0.11423580348491669
# File: LJ004-0225.wav - Median RMS energy: 0.07668303698301315
# File: LJ004-0143.wav - Median RMS energy: 0.11104762554168701
# File: LJ004-0205.wav - Median RMS energy: 0.13609637320041656
# File: LJ004-0240.wav - Median RMS energy: 0.08505485951900482
# File: LJ004-0230.wav - Median RMS energy: 0.07558946311473846
# File: LJ004-0035.wav - Median RMS energy: 0.09852492809295654
# File: LJ004-0121.wav - Median RMS energy: 0.09252166748046875
# File: LJ005-0100.wav - Median RMS energy: 0.09101933240890503
# File: LJ005-0055.wav - Median RMS energy: 0.08003254234790802
# File: LJ004-0052.wav - Median RMS energy: 0.1055164560675621
# File: LJ004-0060.wav - Median RMS energy: 0.08951278775930405
# ...
# File: LJ004-0151.wav - Median RMS energy: 0.11509810388088226
# File: LJ004-0042.wav - Median RMS energy: 0.08525407314300537
# File: LJ004-0029.wav - Median RMS energy: 0.11108861863613129
# File: LJ005-0062.wav - Median RMS energy: 0.06458370387554169
# File: LJ004-0061.wav - Median RMS energy: 0.08341384679079056
# File: LJ004-0107.wav - Median RMS energy: 0.07821619510650635
# File: LJ004-0163.wav - Median RMS energy: 0.08592192828655243
# File: LJ004-0070.wav - Median RMS energy: 0.07672511786222458
# File: LJ004-0180.wav - Median RMS energy: 0.10115472227334976
# File: LJ004-0186.wav - Median RMS energy: 0.11040811240673065
# File: LJ004-0226.wav - Median RMS energy: 0.10575001686811447
# File: LJ004-0128.wav - Median RMS energy: 0.09547586739063263
# File: LJ005-0029.wav - Median RMS energy: 0.1024966686964035
# File: LJ004-0149.wav - Median RMS energy: 0.10103747993707657
# File: LJ004-0135.wav - Median RMS energy: 0.10361620038747787
# File: LJ004-0211.wav - Median RMS energy: 0.08593890070915222
# File: LJ004-0087.wav - Median RMS energy: 0.11412148177623749
# File: LJ004-0185.wav - Median RMS energy: 0.08736753463745117
# File: LJ005-0097.wav - Median RMS energy: 0.08539414405822754
# File: LJ005-0042.wav - Median RMS energy: 0.07817774266004562
# File: LJ005-0048.wav - Median RMS energy: 0.09954193234443665
# File: LJ004-0248.wav - Median RMS energy: 0.1074710562825203
# File: LJ004-0110.wav - Median RMS energy: 0.07632321119308472
# File: LJ004-0234.wav - Median RMS energy: 0.0837617889046669
# File: LJ005-0072.wav - Median RMS energy: 0.08201023936271667
# File: LJ004-0105.wav - Median RMS energy: 0.07937803864479065
# File: LJ004-0050.wav - Median RMS energy: 0.09291964024305344
# File: LJ004-0209.wav - Median RMS energy: 0.10497205704450607
# File: LJ004-0231.wav - Median RMS energy: 0.0803307294845581
# File: LJ004-0085.wav - Median RMS energy: 0.07484987378120422
# File: LJ004-0039.wav - Median RMS energy: 0.10538265109062195
# File: LJ005-0023.wav - Median RMS energy: 0.08431317657232285
# File: LJ005-0103.wav - Median RMS energy: 0.08735621720552444
# File: LJ004-0134.wav - Median RMS energy: 0.09218766540288925
# File: LJ005-0068.wav - Median RMS energy: 0.10647420585155487
# File: LJ004-0046.wav - Median RMS energy: 0.09396388381719589
# File: LJ005-0027.wav - Median RMS energy: 0.09306459873914719
# File: LJ004-0065.wav - Median RMS energy: 0.07861213386058807
# File: LJ005-0054.wav - Median RMS energy: 0.11334741115570068
# File: LJ004-0076.wav - Median RMS energy: 0.08424568921327591
# File: LJ001-0132.wav - Median RMS energy: 0.08014225959777832
# File: LJ003-0256.wav - Median RMS energy: 0.09390901029109955
# File: LJ003-0018.wav - Median RMS energy: 0.08861948549747467
# File: LJ003-0299.wav - Median RMS energy: 0.0899910181760788
# File: LJ001-0138.wav - Median RMS energy: 0.06480178982019424
# File: LJ003-0188.wav - Median RMS energy: 0.07777807861566544
# File: LJ001-0143.wav - Median RMS energy: 0.09781162440776825
# File: LJ003-0028.wav - Median RMS energy: 0.08619911968708038
# File: LJ001-0079.wav - Median RMS energy: 0.10989788174629211
# File: LJ003-0206.wav - Median RMS energy: 0.09279438853263855
# File: LJ001-0181.wav - Median RMS energy: 0.10173793137073517
# File: LJ003-0010.wav - Median RMS energy: 0.09750070422887802
# File: LJ002-0144.wav - Median RMS energy: 0.09467487782239914
# File: LJ002-0178.wav - Median RMS energy: 0.08327382802963257
# File: LJ001-0112.wav - Median RMS energy: 0.0829855278134346
# File: LJ003-0012.wav - Median RMS energy: 0.09156353771686554
# File: LJ003-0348.wav - Median RMS energy: 0.09168612211942673
# File: LJ002-0092.wav - Median RMS energy: 0.10130569338798523
# File: LJ003-0334.wav - Median RMS energy: 0.06193706393241882
# File: LJ001-0103.wav - Median RMS energy: 0.0831487774848938
# File: LJ001-0131.wav - Median RMS energy: 0.08352030813694
# File: LJ003-0057.wav - Median RMS energy: 0.07142011821269989
# File: LJ003-0295.wav - Median RMS energy: 0.09696897119283676
# File: LJ003-0102.wav - Median RMS energy: 0.09075410664081573
# File: LJ003-0100.wav - Median RMS energy: 0.08419359475374222
# File: LJ003-0091.wav - Median RMS energy: 0.09585747122764587
# File: LJ003-0319.wav - Median RMS energy: 0.11315825581550598
# File: LJ002-0132.wav - Median RMS energy: 0.08293920755386353
# File: LJ003-0114.wav - Median RMS energy: 0.09871530532836914
# File: LJ003-0273.wav - Median RMS energy: 0.09385445713996887
# File: LJ003-0196.wav - Median RMS energy: 0.08092236518859863
# File: LJ003-0307.wav - Median RMS energy: 0.08370409905910492
# File: LJ003-0208.wav - Median RMS energy: 0.09671574831008911
# File: LJ003-0251.wav - Median RMS energy: 0.1003996804356575
# File: LJ001-0165.wav - Median RMS energy: 0.09415540099143982
# File: LJ002-0130.wav - Median RMS energy: 0.10264793783426285
# File: LJ002-0166.wav - Median RMS energy: 0.06988026946783066
# File: LJ002-0189.wav - Median RMS energy: 0.10824625939130783
# File: LJ002-0154.wav - Median RMS energy: 0.08547753095626831
# File: LJ003-0054.wav - Median RMS energy: 0.09502938389778137
# File: LJ003-0286.wav - Median RMS energy: 0.0914217084646225
# File: LJ003-0189.wav - Median RMS energy: 0.08627808839082718
# File: LJ003-0191.wav - Median RMS energy: 0.05105731263756752
# File: LJ002-0050.wav - Median RMS energy: 0.09028699994087219
# File: LJ003-0061.wav - Median RMS energy: 0.1218881905078888
# File: LJ003-0239.wav - Median RMS energy: 0.0934251993894577
# File: LJ002-0155.wav - Median RMS energy: 0.07321318238973618
# File: LJ003-0236.wav - Median RMS energy: 0.10602843761444092
# File: LJ002-0228.wav - Median RMS energy: 0.12554386258125305
# File: LJ002-0138.wav - Median RMS energy: 0.11141013354063034
# File: LJ002-0011.wav - Median RMS energy: 0.0996493399143219
# File: LJ001-0024.wav - Median RMS energy: 0.08619304746389389
# File: LJ002-0149.wav - Median RMS energy: 0.1011326014995575
# File: LJ003-0342.wav - Median RMS energy: 0.0835350751876831
# File: LJ001-0022.wav - Median RMS energy: 0.09045222401618958
# File: LJ003-0014.wav - Median RMS energy: 0.08770562708377838
# File: LJ001-0145.wav - Median RMS energy: 0.07660479098558426
# File: LJ003-0082.wav - Median RMS energy: 0.10126285254955292
# File: LJ002-0320.wav - Median RMS energy: 0.10031279921531677
# File: LJ004-0007.wav - Median RMS energy: 0.08773471415042877
# File: LJ001-0021.wav - Median RMS energy: 0.09112144261598587
# File: LJ003-0219.wav - Median RMS energy: 0.09800262749195099
# File: LJ001-0025.wav - Median RMS energy: 0.08919766545295715
# File: LJ003-0233.wav - Median RMS energy: 0.0899481326341629
# File: LJ002-0056.wav - Median RMS energy: 0.08604080229997635
# File: LJ003-0336.wav - Median RMS energy: 0.08971954882144928
# File: LJ003-0220.wav - Median RMS energy: 0.09639433026313782
# File: LJ003-0080.wav - Median RMS energy: 0.09884380549192429
# File: LJ003-0084.wav - Median RMS energy: 0.09918104112148285
# File: LJ003-0140.wav - Median RMS energy: 0.0815533995628357
# File: LJ003-0270.wav - Median RMS energy: 0.0901893824338913
# File: LJ003-0060.wav - Median RMS energy: 0.09608255326747894
# File: LJ003-0005.wav - Median RMS energy: 0.08349119871854782
# File: LJ002-0017.wav - Median RMS energy: 0.07340018451213837
# File: LJ002-0124.wav - Median RMS energy: 0.11282813549041748
# File: LJ001-0051.wav - Median RMS energy: 0.09368012100458145
# File: LJ003-0215.wav - Median RMS energy: 0.08386190235614777
# File: LJ001-0004.wav - Median RMS energy: 0.09733527153730392
# File: LJ001-0168.wav - Median RMS energy: 0.08805277943611145
# File: LJ004-0024.wav - Median RMS energy: 0.10214641690254211
# File: LJ004-0002.wav - Median RMS energy: 0.08279667794704437
# File: LJ001-0034.wav - Median RMS energy: 0.09228683263063431
# File: LJ003-0333.wav - Median RMS energy: 0.07759963721036911
# File: LJ002-0133.wav - Median RMS energy: 0.07497534900903702
# File: LJ003-0047.wav - Median RMS energy: 0.09929022192955017
# File: LJ003-0074.wav - Median RMS energy: 0.09050319343805313
# File: LJ003-0122.wav - Median RMS energy: 0.0975748598575592
# File: LJ003-0050.wav - Median RMS energy: 0.07822833210229874
# File: LJ002-0174.wav - Median RMS energy: 0.09720836579799652
# File: LJ002-0071.wav - Median RMS energy: 0.10250768065452576
# File: LJ001-0083.wav - Median RMS energy: 0.10257263481616974
# File: LJ002-0195.wav - Median RMS energy: 0.10010270774364471
# File: LJ003-0062.wav - Median RMS energy: 0.08270993828773499
# File: LJ002-0142.wav - Median RMS energy: 0.11844856292009354
# File: LJ004-0010.wav - Median RMS energy: 0.0972382053732872
# File: LJ002-0125.wav - Median RMS energy: 0.0975702702999115
# File: LJ003-0013.wav - Median RMS energy: 0.07605324685573578
# File: LJ001-0140.wav - Median RMS energy: 0.11696109920740128
# File: LJ001-0023.wav - Median RMS energy: 0.09438896924257278
# File: LJ001-0105.wav - Median RMS energy: 0.09703957289457321
# File: LJ001-0038.wav - Median RMS energy: 0.08476032316684723
# File: LJ001-0081.wav - Median RMS energy: 0.09449950605630875
# File: LJ002-0086.wav - Median RMS energy: 0.08787644654512405
# File: LJ001-0010.wav - Median RMS energy: 0.08283762633800507
# File: LJ002-0213.wav - Median RMS energy: 0.07361453771591187
# File: LJ001-0082.wav - Median RMS energy: 0.09892630577087402
# File: LJ003-0155.wav - Median RMS energy: 0.09255514293909073
# File: LJ001-0158.wav - Median RMS energy: 0.07025878131389618
# File: LJ001-0030.wav - Median RMS energy: 0.08363234996795654
# File: LJ001-0179.wav - Median RMS energy: 0.09511597454547882
# File: LJ003-0143.wav - Median RMS energy: 0.10017254948616028
# File: LJ002-0106.wav - Median RMS energy: 0.09635457396507263
# File: LJ001-0033.wav - Median RMS energy: 0.08040232956409454
# File: LJ001-0045.wav - Median RMS energy: 0.09006486088037491
# File: LJ003-0124.wav - Median RMS energy: 0.10869359970092773
# File: LJ002-0229.wav - Median RMS energy: 0.07270823419094086
# File: LJ001-0153.wav - Median RMS energy: 0.08561281859874725
# File: LJ002-0019.wav - Median RMS energy: 0.09530662000179291
# File: LJ003-0211.wav - Median RMS energy: 0.08510665595531464
# File: LJ002-0117.wav - Median RMS energy: 0.07966255396604538
# File: LJ001-0139.wav - Median RMS energy: 0.09882837533950806
# File: LJ001-0026.wav - Median RMS energy: 0.0967688113451004
# File: LJ002-0022.wav - Median RMS energy: 0.08942295610904694
# File: LJ003-0015.wav - Median RMS energy: 0.10157343745231628
# File: LJ001-0185.wav - Median RMS energy: 0.10385802388191223
# File: LJ002-0110.wav - Median RMS energy: 0.10028284043073654
# File: LJ002-0317.wav - Median RMS energy: 0.09604644030332565
# File: LJ001-0150.wav - Median RMS energy: 0.09708087146282196
# File: LJ002-0318.wav - Median RMS energy: 0.09348466992378235
# File: LJ003-0234.wav - Median RMS energy: 0.09588613361120224
# File: LJ001-0171.wav - Median RMS energy: 0.10279786586761475
# File: LJ001-0125.wav - Median RMS energy: 0.08091061562299728
# File: LJ002-0246.wav - Median RMS energy: 0.09208100289106369
# File: LJ001-0152.wav - Median RMS energy: 0.09680213034152985
# File: LJ002-0173.wav - Median RMS energy: 0.07318015396595001
# File: LJ002-0143.wav - Median RMS energy: 0.11461712419986725
# File: LJ003-0243.wav - Median RMS energy: 0.101527139544487
# File: LJ001-0135.wav - Median RMS energy: 0.08232028782367706
# File: LJ004-0001.wav - Median RMS energy: 0.08268123120069504
# File: LJ001-0095.wav - Median RMS energy: 0.11845239996910095
# File: LJ002-0300.wav - Median RMS energy: 0.10555215179920197
# File: LJ003-0262.wav - Median RMS energy: 0.10211344808340073
# File: LJ002-0014.wav - Median RMS energy: 0.09810981154441833
# File: LJ004-0019.wav - Median RMS energy: 0.08229168504476547
# File: LJ001-0028.wav - Median RMS energy: 0.10192772001028061
# File: LJ003-0089.wav - Median RMS energy: 0.09757287055253983
# File: LJ003-0111.wav - Median RMS energy: 0.10790775716304779
# File: LJ002-0266.wav - Median RMS energy: 0.10991056263446808
# File: LJ003-0086.wav - Median RMS energy: 0.07895007729530334
# File: LJ002-0205.wav - Median RMS energy: 0.09634893387556076
# File: LJ003-0195.wav - Median RMS energy: 0.09435363858938217
# File: LJ001-0088.wav - Median RMS energy: 0.08804748207330704
# File: LJ001-0060.wav - Median RMS energy: 0.08542200177907944
# File: LJ001-0040.wav - Median RMS energy: 0.09123197197914124
# File: LJ003-0144.wav - Median RMS energy: 0.09442755579948425
# File: LJ002-0227.wav - Median RMS energy: 0.08915551751852036
# File: LJ003-0175.wav - Median RMS energy: 0.09973838925361633
# File: LJ002-0051.wav - Median RMS energy: 0.08549398183822632
# File: LJ003-0190.wav - Median RMS energy: 0.10778235644102097
# File: LJ003-0029.wav - Median RMS energy: 0.09254186600446701
# File: LJ003-0098.wav - Median RMS energy: 0.08298853784799576
# File: LJ001-0067.wav - Median RMS energy: 0.09099634736776352
# File: LJ003-0227.wav - Median RMS energy: 0.07130719721317291
# File: LJ002-0062.wav - Median RMS energy: 0.07523882389068604
# File: LJ001-0052.wav - Median RMS energy: 0.09391720592975616
# File: LJ001-0172.wav - Median RMS energy: 0.08921261876821518
# File: LJ002-0299.wav - Median RMS energy: 0.09984302520751953
# File: LJ002-0194.wav - Median RMS energy: 0.08781316131353378
# File: LJ002-0068.wav - Median RMS energy: 0.09316252171993256
# File: LJ002-0297.wav - Median RMS energy: 0.08382752537727356
# File: LJ001-0069.wav - Median RMS energy: 0.09571868181228638
# File: LJ003-0083.wav - Median RMS energy: 0.08713886141777039
# File: LJ003-0085.wav - Median RMS energy: 0.08077169209718704
# File: LJ001-0136.wav - Median RMS energy: 0.10890145599842072
# File: LJ003-0113.wav - Median RMS energy: 0.10785317420959473
# File: LJ004-0017.wav - Median RMS energy: 0.0963858962059021
# File: LJ001-0044.wav - Median RMS energy: 0.10811980068683624
# File: LJ002-0188.wav - Median RMS energy: 0.09209373593330383
# File: LJ001-0005.wav - Median RMS energy: 0.08059049397706985
# File: LJ001-0102.wav - Median RMS energy: 0.09577196091413498
# File: LJ001-0162.wav - Median RMS energy: 0.0809670090675354
# File: LJ003-0126.wav - Median RMS energy: 0.06717878580093384
# File: LJ003-0187.wav - Median RMS energy: 0.1104922741651535
# File: LJ001-0055.wav - Median RMS energy: 0.07905660569667816
# File: LJ003-0289.wav - Median RMS energy: 0.07373365759849548
# File: LJ001-0177.wav - Median RMS energy: 0.07501868903636932
# File: LJ003-0292.wav - Median RMS energy: 0.08915024995803833
# File: LJ003-0105.wav - Median RMS energy: 0.11233574897050858
# File: LJ003-0149.wav - Median RMS energy: 0.10539492964744568
# File: LJ003-0257.wav - Median RMS energy: 0.11063320934772491
# File: LJ003-0078.wav - Median RMS energy: 0.09923577308654785
# File: LJ001-0174.wav - Median RMS energy: 0.09885047376155853
# File: LJ003-0056.wav - Median RMS energy: 0.08875834196805954
# File: LJ002-0310.wav - Median RMS energy: 0.08261552453041077
# File: LJ002-0270.wav - Median RMS energy: 0.08852611482143402
# File: LJ002-0263.wav - Median RMS energy: 0.0780567154288292
# File: LJ003-0255.wav - Median RMS energy: 0.0816567987203598
# File: LJ003-0210.wav - Median RMS energy: 0.08787257224321365
# File: LJ001-0106.wav - Median RMS energy: 0.11153893917798996
# File: LJ001-0074.wav - Median RMS energy: 0.09684865176677704
# File: LJ003-0178.wav - Median RMS energy: 0.07959901541471481
# File: LJ001-0149.wav - Median RMS energy: 0.08124624192714691
# File: LJ003-0335.wav - Median RMS energy: 0.09247307479381561
# File: LJ002-0003.wav - Median RMS energy: 0.09541875869035721
# File: LJ002-0326.wav - Median RMS energy: 0.08925232291221619
# File: LJ002-0196.wav - Median RMS energy: 0.10031479597091675
# File: LJ002-0063.wav - Median RMS energy: 0.089506596326828
# File: LJ001-0164.wav - Median RMS energy: 0.07418093085289001
# File: LJ002-0021.wav - Median RMS energy: 0.09440946578979492
# File: LJ002-0093.wav - Median RMS energy: 0.10933831334114075
# File: LJ001-0063.wav - Median RMS energy: 0.07548357546329498
# File: LJ002-0296.wav - Median RMS energy: 0.11039652675390244
# File: LJ001-0108.wav - Median RMS energy: 0.09448161721229553
# File: LJ003-0274.wav - Median RMS energy: 0.0796634703874588
# File: LJ002-0053.wav - Median RMS energy: 0.08802738785743713
# File: LJ002-0193.wav - Median RMS energy: 0.10209278762340546
# File: LJ001-0116.wav - Median RMS energy: 0.07935215532779694
# File: LJ003-0268.wav - Median RMS energy: 0.08778689801692963

# %%
import os
import wave
import math

directory = "/content/drive/MyDrive/wavs/backup"  
total_duration = 0

for filename in os.listdir(directory):
    if filename.endswith(".wav"):
        wav_file = wave.open(os.path.join(directory, filename), 'r')
        frames = wav_file.getnframes()
        rate = wav_file.getframerate()
        duration = frames / float(rate)
        total_duration += duration

total_duration_minutes = math.floor(total_duration / 60)
print("Total duration in minutes: ", total_duration_minutes)
# Out:
# Total duration in minutes:  105

# %% [markdown]
# **Split Audio Samples with SOX**

# %%
#@title
# %cd /content
# !sudo apt install sox

# %%
SP_WORKDIR = "/content/drive/MyDrive/wavs/" 
SP_EXT = "wav"

# %%
SP_SCRIPT="""
#!/bin/bash
EXT='"""+SP_EXT+"""'
WORK_DIR='"""+SP_WORKDIR+"""'
rename 's/\.([^.]+)$/.\L$1/' "$WORK_DIR"/*
cd "$WORK_DIR"
mkdir backup-presplit
mv *.$EXT backup-presplit
cd backup-presplit
rm -rf splits
mkdir splits
for FILE in *.wav; do sox "$FILE" splits/"$FILE" --show-progress silence 1 0.2 0.1% 1 0.2 0.1% : newfile : restart ; done
cd splits
mkdir resplit
for FILE in *.wav; do sox "$FILE" resplit/"$FILE" --show-progress trim 0 9 : newfile : restart ; done
cd resplit
find . -name "*.wav" -type f -size -35k -delete
mv *.wav $WORK_DIR
cd $WORK_DIR
rm -rf splits
ls -al
"""
with open('/content/drive/MyDrive/script-split-samples.sh', 'w') as file:
  file.write(SP_SCRIPT)

# %%
# !sh /content/drive/MyDrive/script-split-samples.sh

# %% [markdown]
# **Install OpenAI Whisper STT+Translation (https://github.com/openai/whisper)**

# %% [markdown]
# **Run Whisper on generated audio clips.**
# Transcripts will be formatted for the VCTK-style dataset and placed in the<br>
# ->dataset directory<br>
# ---->txt<br>
# -------->speakername<br>

# %% [markdown]
# datasetfolder<br>
# ->txt<br>
# ---->nameone<br>
# ---->nametwo<br>
# ->wav48_silence_trimmed<br>
# ---->nameone<br>
# ---->nametwo<br>

# %% [markdown]
# **Select Whisper STT model. Large-v2 slowest, most accurate but most memory usage**

# %%
whisper_model = "large-v2" #@param ["large-v2", "large-v1", "medium.en", "small.en", "base.en"]

# %%
#@title
import whisper
import os, os.path
import glob
import pandas as pd

from pathlib import Path


#model = whisper.load_model("medium.en")
model = whisper.load_model(whisper_model)

# %%
newspeakername = "spongebob"

# %%
from transformers import WhisperProcessor, WhisperForConditionalGeneration
options = dict(language="english", beam_size=5, best_of=5)
transcribe_options = dict(task="transcribe", **options)

#@title
wavs = '/content/drive/MyDrive/'+ds_name+'/wav48_silence_trimmed/'+newspeakername

paths = glob.glob(os.path.join(wavs, '*.flac'))
print(len(paths))
all_filenames = []
transcript_text = []
try: 
	os.mkdir('/content/drive/MyDrive/'+ds_name+'/txt/') 
except OSError as error: 
	print(error)  
try: 
	os.mkdir('/content/drive/MyDrive/'+ds_name+'/txt/'+newspeakername+'/') 
except OSError as error: 
	print(error)  

for filepath in paths:
	base = os.path.basename(filepath)
	all_filenames.append(base)
	result = model.transcribe(filepath, **options)
	output = result["text"].lstrip()
	output = output.replace("\n","")
	print(output)
	thefile = str(os.path.basename(filepath).lstrip(".")).rsplit(".")[0]
	thefile = thefile[:-5]
	print(thefile)
	outfilepath = '/content/drive/MyDrive/'+ds_name+'/txt/'+newspeakername+'/'+thefile+'.txt'
	with open(outfilepath, 'w', encoding='utf-8') as indfile:
		indfile.write(output)

# %% [markdown]
# **Check dataset for empty transcript files.Bad file sets will be moved to a folder called badfiles in your dataset directory.**

# %% [markdown]
# checks for empty transcript files and transcripts containing characters not matching this regex pattern:
# [A-Z0-9a-zŽžÀ-ÿ]
#
# Moves orphaned flac files and mistranscriptions to badfiles directory

# %%
check_datasetbase = "newdatasetspong" 
check_speakername = "spongebob"

# %%
#@title
import re
import os, os.path
import glob
import shutil
rootpath="/content/drive/MyDrive/"
ds_name2=check_datasetbase
newspeakername2=check_speakername
flac = rootpath+ds_name2+'/wav48_silence_trimmed/'+newspeakername2+'/'
# wav = rootpath+ds_name2+'/wavs/'
wav = '/content/drive/MyDrive/wavs'
txt = rootpath+ds_name2+'/txt/'+newspeakername2+'/'
outfilepath = rootpath+ds_name2+'/txt/'+newspeakername2
backup_path = rootpath+ds_name2+'/badfiles/'
if not os.path.exists(backup_path):
    os.makedirs(backup_path)
searchstr = "(?i)(?!(?![×Þß÷þø])[a-zÀ-ÿ])\S"
txtfiles = glob.glob(os.path.join(txt, '*.txt'))
EMPTY_TRANSCRIPTS = []
for txts in txtfiles:
    with open(txts, 'r', encoding='utf-8') as outfile:
        state = os.stat(txts).st_size == 0
        if state==True:
            print(str(txts))
            basename_without_ext = os.path.splitext(os.path.basename(txts))[0]
            print(basename_without_ext)
            bad_wav = basename_without_ext+".wav"
            bad_txt = basename_without_ext+".txt"
            bad_flac = basename_without_ext+"_mic1.flac"
#            print(bad_wav)
#            print(bad_txt)
            if os.path.exists(wav+bad_wav):
                bad_wav_file_size = os.path.getsize(wav+bad_wav)
            if os.path.exists(txt+bad_txt):
                bad_txt_file_size = os.path.getsize(txt+bad_txt)
            if os.path.exists(flac+bad_flac):
                bad_flac_file_size = os.path.getsize(flac+bad_flac)
#            print(bad_wav_file_size)
#            print(bad_txt_file_size)
            if os.path.exists(wav+bad_wav):
                shutil.move(wav+bad_wav, backup_path+bad_wav)
            if os.path.exists(txt+bad_txt):
                shutil.move(txt+bad_txt, backup_path+bad_txt)
            if os.path.exists(flac+bad_flac):
                shutil.move(flac+bad_flac, backup_path+bad_flac)
        if state==False:
            for line in outfile:
                match = re.search('^((?![A-Z0-9a-zŽžÀ-ÿ]).)*$', line)
                if match:
                    print(line)
                    basename_without_ext = os.path.splitext(os.path.basename(txts))[0]
                    print(basename_without_ext)
                    bad_wav = basename_without_ext+".wav"
                    bad_txt = basename_without_ext+".txt"
                    bad_flac = basename_without_ext+"_mic1.flac"
                    if os.path.exists(wav+bad_wav):
                        bad_wav_file_size = os.path.getsize(wav+bad_wav)
                    if os.path.exists(txt+bad_txt):
                        bad_txt_file_size = os.path.getsize(txt+bad_txt)
                    if os.path.exists(flac+bad_flac):
                        bad_flac_file_size = os.path.getsize(flac+bad_flac)
                    if os.path.exists(wav+bad_wav):
                        shutil.move(wav+bad_wav, backup_path+bad_wav)
                    if os.path.exists(txt+bad_txt):
                        shutil.move(txt+bad_txt, backup_path+bad_txt)
                    if os.path.exists(flac+bad_flac):
                        shutil.move(flac+bad_flac, backup_path+bad_flac)

# %% [markdown]
# **Scan for orphaned transcriptions or audio files.  Orphaned files moved to missing directory.**

# %%
#@title
import re
import os, os.path
import glob
import shutil

rootpath="/content/drive/MyDrive/"
ds_name2=or_datasetbase
newspeakername2=or_speakername
flac = rootpath+ds_name2+'/wav48_silence_trimmed/'+newspeakername2+'/'
# wav = rootpath+ds_name2+'/wavs/'
wav = '/content/drive/MyDrive/wavs'
txt = rootpath+ds_name2+'/txt/'+newspeakername2+'/'
outfilepath = rootpath+ds_name2+'/txt/'+newspeakername2
mis_path = rootpath+ds_name2+'/missing/'+newspeakername2+'/'
backup_path = rootpath+ds_name2+'/badfiles/'+newspeakername2+'/'

if not os.path.exists(mis_path):
	os.makedirs(mis_path)

txtfiles = glob.glob(os.path.join(txt, '*.txt'))
flacfiles = glob.glob(os.path.join(flac, '*.flac'))

EMPTY_TRANSCRIPTS = []
for txts in txtfiles:
	basename_without_ext = os.path.splitext(os.path.basename(txts))[0]
	wav_file = basename_without_ext+".wav"
	txt_file = basename_without_ext+".txt"
	flac_file = basename_without_ext+"_mic1.flac"
	if not os.path.exists(str(flac + flac_file)):
		print("flac " + flac_file + " missing")
		if os.path.exists(txt+txt_file):
			print(str(txt+txt_file))
			shutil.move(txt+txt_file, mis_path+txt_file)

for flacs in flacfiles:
	flac_base = os.path.splitext(os.path.basename(flacs))[0]
	flac_base = flac_base[:-5]
	wav_file = flac_base+".wav"
	txt_file = flac_base+".txt"
	flac_file = flac_base+"_mic1.flac"
	if not os.path.exists(str(txt + txt_file)):
		print("text " + txt_file + " missing")
		if os.path.exists(flac+flac_file):
			print(str(flac+flac_file))
			shutil.move(flac+flac_file, mis_path+flac_file)

# %% [markdown]
# **Now the data is ready to be used**
